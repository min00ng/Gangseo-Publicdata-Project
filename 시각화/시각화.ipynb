# %%
import pandas as pd
import matplotlib as mp

# %%
df=pd.read_csv('강서구데이터.csv')
df
# Out:
#                시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0          천사노인요양원  A0007      (노인) 노인요양시설      노인의료복지시설      자치구  김샛별
# 1    강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구  서순애
# 2       우리모두데이케어센터  A1074    (노인) 재가노인복지시설      재가노인복지시설      자치구  김기철
# 3        한마음방문요양센터  A1153    (노인) 재가노인복지시설      재가노인복지시설      자치구  이은점
# 4      참사랑재가노인지원센터  A1193    (노인) 재가노인복지시설      재가노인복지시설      자치구  조병기
# ..             ...    ...              ...           ...      ...  ...
# 184     등촌9종합사회복지관  Z5116       (일반) 사회복지관      일반사회복지시설      자치구  김기철
# 185    방화11종합사회복지관  Z5139       (일반) 사회복지관      일반사회복지시설      자치구  김상진
# 186     방화2종합사회복지관  Z5140       (일반) 사회복지관      일반사회복지시설      자치구  김지연
# 187     방화6종합사회복지관  Z5141       (일반) 사회복지관      일반사회복지시설      자치구  김성미
# 188      강서구치매지원센터  Z5448  (노인) (기타)노인복지시설          노인기타      자치구  정지향
#
#           시군구코드 시군구명                                시설주소
# 0    1150000000  강서구             서울특별시 강서구 강서로45다길 30-22
# ...

# %%
#결측치 확인
df.head()
# Out:
#              시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분 시설장명  \
# 0        천사노인요양원  A0007      (노인) 노인요양시설      노인의료복지시설      자치구  김샛별
# 1  강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구  서순애
# 2     우리모두데이케어센터  A1074    (노인) 재가노인복지시설      재가노인복지시설      자치구  김기철
# 3      한마음방문요양센터  A1153    (노인) 재가노인복지시설      재가노인복지시설      자치구  이은점
# 4    참사랑재가노인지원센터  A1193    (노인) 재가노인복지시설      재가노인복지시설      자치구  조병기
#
#         시군구코드 시군구명                         시설주소
# 0  1150000000  강서구      서울특별시 강서구 강서로45다길 30-22
# 1  1150000000  강서구        서울특별시 강서구 초록마을로15길 12
# 2  1150000000  강서구         서울특별시 강서구 화곡로63가길 92
# 3  1150000000  강서구  서울특별시 강서구 초록마을로14길 44 (화곡동)
# 4  1150000000  강서구          서울특별시 강서구 곰달래로 852층

# %%
#결측치 확인
df.isna()
# Out:
#        시설명   시설코드  시설종류명(시설유형)  시설종류상세명(시설종류)  자치구(시)구분   시설장명  시군구코드   시군구명  \
# 0    False  False        False          False     False  False  False  False
# 1    False  False        False          False     False  False  False  False
# 2    False  False        False          False     False  False  False  False
# 3    False  False        False          False     False  False  False  False
# 4    False  False        False          False     False  False  False  False
# ..     ...    ...          ...            ...       ...    ...    ...    ...
# 184  False  False        False          False     False  False  False  False
# 185  False  False        False          False     False  False  False  False
# 186  False  False        False          False     False  False  False  False
# 187  False  False        False          False     False  False  False  False
# 188  False  False        False          False     False  False  False  False
#
#       시설주소
# 0    False
# 1    False
# ...

# %%
df_m=pd.read_csv('강서구인구.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/cf/clt_ykjs2bq_l1v90mdwsgfm0000gn/T/ipykernel_3134/1519786809.py in <module>
# ----> 1 df_m=pd.read_csv('강서구인구.csv')
#
# ~/opt/anaconda3/envs/myenv1/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import folium
#서울 지도 만들기[위도,경도]
seoul_map = folium.Map(location=[37.55,126.98],zoom_start=12)
#지도 html 파일로 저장하기
seoul_map.save('./seoul.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
